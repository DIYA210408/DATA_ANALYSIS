# %%
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6b2d65b2-0616-4421-b5f4-c23501a80662" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b2d65b2-0616-4421-b5f4-c23501a80662">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("1000 Sales Records.csv")

# %%
df.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
df1 = df.iloc[:500]
df2 = df.iloc[500:]

vertical_concat = pd.concat([df1, df2], ignore_index=True)

print(vertical_concat)
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
left = df[['Region','Country','Item Type']]
right = df[['Units Sold','Total Revenue','Total Profit']]

horizontal_concat = pd.concat([left, right], axis=1)

print(horizontal_concat)
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#      Units Sold  Total Revenue  Total Profit
# 0          8446     3692591.20    1468506.02
# 1          3018      464953.08     190526.34
# ...

# %%
left = df[['Order ID','Country']]

right = df[['Order ID','Total Revenue']]

merged = pd.merge(left,right,on='Order ID')

merged.head()
# Out:
#     Order ID Country  Total Revenue
# 0  686800706   Libya     3692591.20
# 1  185941302  Canada      464953.08
# 2  246222341   Libya      387259.76
# 3  161442649   Japan      683335.40
# 4  645713555    Chad       91853.85

# %%
df['Profit Percentage'] = (df['Total Profit']/df['Total Revenue'])*100

df.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit  Profit Percentage
# ...

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price    Unit Cost  Total Revenue  \
# count  1.000000e+03  1000.000000  1000.00000  1000.000000   1.000000e+03
# mean   5.496813e+08  5053.988000   262.10684   184.965110   1.327322e+06
# std    2.571334e+08  2901.375317   216.02106   175.289311   1.486515e+06
# min    1.029280e+08    13.000000     9.33000     6.920000   2.043250e+03
# 25%    3.280740e+08  2420.250000    81.73000    56.670000   2.811919e+05
# 50%    5.566097e+08  5184.000000   154.06000    97.440000   7.549392e+05
# 75%    7.696945e+08  7536.750000   421.89000   263.330000   1.733503e+06
# max    9.955298e+08  9998.000000   668.27000   524.960000   6.617210e+06
#
#          Total Cost  Total Profit  Profit Percentage
# count  1.000000e+03  1.000000e+03        1000.000000
# mean   9.361192e+05  3.912026e+05          34.333600
# std    1.162571e+06  3.836402e+05          12.848772
# min    1.416750e+03  5.326100e+02          13.558036
# ...

# %%
df['Region'].value_counts()
# Out:
# Region
# Europe                               267
# Sub-Saharan Africa                   262
# Middle East and North Africa         138
# Asia                                 136
# Central America and the Caribbean     99
# Australia and Oceania                 79
# North America                         19
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# Cuba              11
# Zimbabwe          10
# Bahrain           10
# Czech Republic    10
# Malaysia          10
#                   ..
# Latvia             2
# Dominica           2
# Cameroon           1
# Malta              1
# Kosovo             1
# Name: count, Length: 185, dtype: int64

# %%
df['Item Type'].value_counts()
# Out:
# Item Type
# Beverages          101
# Vegetables          97
# Office Supplies     89
# Baby Food           87
# Personal Care       87
# Snacks              82
# Cereal              79
# Clothes             78
# Meat                78
# Household           77
# Cosmetics           75
# Fruits              70
# Name: count, dtype: int64

# %%
df['Sales Channel'].value_counts()
# Out:
# Sales Channel
# Offline    520
# Online     480
# Name: count, dtype: int64

# %%
sample = df[['Region','Country','Item Type']].head()

stacked = sample.stack()

stacked
# Out:
# 0  Region       Middle East and North Africa
#    Country                             Libya
#    Item Type                       Cosmetics
# 1  Region                      North America
#    Country                            Canada
#    Item Type                      Vegetables
# 2  Region       Middle East and North Africa
#    Country                             Libya
#    Item Type                       Baby Food
# 3  Region                               Asia
#    Country                             Japan
#    Item Type                          Cereal
# 4  Region                 Sub-Saharan Africa
#    Country                              Chad
#    Item Type                          Fruits
# dtype: object

# %%
stacked.unstack()
# Out:
#                          Region Country   Item Type
# 0  Middle East and North Africa   Libya   Cosmetics
# 1                 North America  Canada  Vegetables
# 2  Middle East and North Africa   Libya   Baby Food
# 3                          Asia   Japan      Cereal
# 4            Sub-Saharan Africa    Chad      Fruits

# %%
series1 = df['Country'].head()

series2 = df['Region'].head()

frame = pd.concat([series1,series2],keys=['Country','Region'])

frame
# Out:
# Country  0                           Libya
#          1                          Canada
#          2                           Libya
#          3                           Japan
#          4                            Chad
# Region   0    Middle East and North Africa
#          1                   North America
#          2    Middle East and North Africa
#          3                            Asia
#          4              Sub-Saharan Africa
# dtype: object

# %%
frame.unstack()
# Out:
#                                     0              1  \
# Country                         Libya         Canada
# Region   Middle East and North Africa  North America
#
#                                     2      3                   4
# Country                         Libya  Japan                Chad
# Region   Middle East and North Africa   Asia  Sub-Saharan Africa

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit',
#        'Profit Percentage'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             1000 non-null   object
#  1   Country            1000 non-null   object
#  2   Item Type          1000 non-null   object
#  3   Sales Channel      1000 non-null   object
#  4   Order Priority     1000 non-null   object
#  5   Order Date         1000 non-null   object
#  6   Order ID           1000 non-null   int64
#  7   Ship Date          1000 non-null   object
#  8   Units Sold         1000 non-null   int64
#  9   Unit Price         1000 non-null   float64
#  10  Unit Cost          1000 non-null   float64
#  11  Total Revenue      1000 non-null   float64
#  12  Total Cost         1000 non-null   float64
#  13  Total Profit       1000 non-null   float64
#  14  Profit Percentage  1000 non-null   float64
# dtypes: float64(6), int64(2), object(7)
# ...

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price    Unit Cost  Total Revenue  \
# count  1.000000e+03  1000.000000  1000.00000  1000.000000   1.000000e+03
# mean   5.496813e+08  5053.988000   262.10684   184.965110   1.327322e+06
# std    2.571334e+08  2901.375317   216.02106   175.289311   1.486515e+06
# min    1.029280e+08    13.000000     9.33000     6.920000   2.043250e+03
# 25%    3.280740e+08  2420.250000    81.73000    56.670000   2.811919e+05
# 50%    5.566097e+08  5184.000000   154.06000    97.440000   7.549392e+05
# 75%    7.696945e+08  7536.750000   421.89000   263.330000   1.733503e+06
# max    9.955298e+08  9998.000000   668.27000   524.960000   6.617210e+06
#
#          Total Cost  Total Profit  Profit Percentage
# count  1.000000e+03  1.000000e+03        1000.000000
# mean   9.361192e+05  3.912026e+05          34.333600
# std    1.162571e+06  3.836402e+05          12.848772
# min    1.416750e+03  5.326100e+02          13.558036
# ...

# %%
df.isnull().sum()
# Out:
# Region               0
# Country              0
# Item Type            0
# Sales Channel        0
# Order Priority       0
# Order Date           0
# Order ID             0
# Ship Date            0
# Units Sold           0
# Unit Price           0
# Unit Cost            0
# Total Revenue        0
# Total Cost           0
# Total Profit         0
# Profit Percentage    0
# dtype: int64

# %%
missing = pd.DataFrame({
    'Total': df.isnull().sum(),
    'Percent': (df.isnull().sum()/len(df))*100
})

missing.sort_values('Percent', ascending=False)
# Out:
#                    Total  Percent
# Region                 0      0.0
# Country                0      0.0
# Item Type              0      0.0
# Sales Channel          0      0.0
# Order Priority         0      0.0
# Order Date             0      0.0
# Order ID               0      0.0
# Ship Date              0      0.0
# Units Sold             0      0.0
# Unit Price             0      0.0
# Unit Cost              0      0.0
# Total Revenue          0      0.0
# Total Cost             0      0.0
# Total Profit           0      0.0
# Profit Percentage      0      0.0

# %%
df = df.loc[:, (df.isnull().mean() < 0.15)]

# %%
df.isnull().sum()
# Out:
# Region               0
# Country              0
# Item Type            0
# Sales Channel        0
# Order Priority       0
# Order Date           0
# Order ID             0
# Ship Date            0
# Units Sold           0
# Unit Price           0
# Unit Cost            0
# Total Revenue        0
# Total Cost           0
# Total Profit         0
# Profit Percentage    0
# dtype: int64

# %%
sns.histplot(df['Total Revenue'], kde=True)
plt.show()

# %%
print(df['Total Revenue'].skew())
# Out:
# 1.6315375163209798

# %%
print(df['Total Revenue'].kurt())
# Out:
# 2.068241241926463

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaled = scaler.fit_transform(df[['Total Revenue']])

scaled[:10]
# Out:
# array([[ 1.59194732],
#        [-0.58041831],
#        [-0.63270989],
#        [-0.43343583],
#        [-0.83153318],
#        [ 0.42576394],
#        [-0.49961332],
#        [-0.35650654],
#        [-0.64159556],
#        [-0.39564226]])

# %%
sns.scatterplot(
    data=df,
    x='Units Sold',
    y='Total Revenue'
)

plt.show()

# %%
sns.scatterplot(
    data=df,
    x='Total Cost',
    y='Total Revenue'
)

plt.show()

# %%
plt.figure(figsize=(14,6))

sns.boxplot(
    data=df,
    x='Item Type',
    y='Total Revenue'
)

plt.xticks(rotation=90)

plt.show()

# %%
corr = df.corr(numeric_only=True)

corr
# Out:
#                    Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID           1.000000    0.010266   -0.033436  -0.035550      -0.022079
# Units Sold         0.010266    1.000000    0.004212   0.002574       0.527945
# Unit Price        -0.033436    0.004212    1.000000   0.986735       0.730752
# Unit Cost         -0.035550    0.002574    0.986735   1.000000       0.717999
# Total Revenue     -0.022079    0.527945    0.730752   0.717999       1.000000
# Total Cost        -0.025629    0.479713    0.745538   0.753678       0.987779
# Total Profit      -0.007886    0.591957    0.572235   0.498156       0.881429
# Profit Percentage  0.042535   -0.019261   -0.463389  -0.572012      -0.338114
#
#                    Total Cost  Total Profit  Profit Percentage
# Order ID            -0.025629     -0.007886           0.042535
# Units Sold           0.479713      0.591957          -0.019261
# Unit Price           0.745538      0.572235          -0.463389
# ...

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm'
)

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(
    data=df,
    x='Region'
)

plt.xticks(rotation=45)

plt.show()

# %%
df['Sales Channel'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.ylabel('')

plt.show()

# %%
sns.pairplot(
    df[['Units Sold',
        'Unit Price',
        'Unit Cost',
        'Total Revenue',
        'Total Cost',
        'Total Profit']]
)

plt.show()

# %%
df.groupby('Region')['Total Revenue'].mean()
# Out:
# Region
# Asia                                 1.232903e+06
# Australia and Oceania                1.337843e+06
# Central America and the Caribbean    1.454521e+06
# Europe                               1.322725e+06
# Middle East and North Africa         1.268888e+06
# North America                        1.313768e+06
# Sub-Saharan Africa                   1.361543e+06
# Name: Total Revenue, dtype: float64

# %%
df.groupby('Region')['Total Revenue'].median()
# Out:
# Region
# Asia                                 696313.820
# Australia and Oceania                717180.750
# Central America and the Caribbean    641145.760
# Europe                               739279.200
# Middle East and North Africa         758296.725
# North America                        734580.160
# Sub-Saharan Africa                   869457.095
# Name: Total Revenue, dtype: float64

# %%
df.groupby('Region')['Total Revenue'].max()
# Out:
# Region
# Asia                                 6557065.24
# Australia and Oceania                6580454.69
# Central America and the Caribbean    6354579.43
# Europe                               6617209.54
# Middle East and North Africa         6160781.13
# North America                        6216247.54
# Sub-Saharan Africa                   6456747.15
# Name: Total Revenue, dtype: float64

# %%
df.groupby('Region')['Total Revenue'].min()
# Out:
# Region
# Asia                                  3592.05
# Australia and Oceania                31506.80
# Central America and the Caribbean    16056.93
# Europe                                2061.93
# Middle East and North Africa          5409.30
# North America                        43934.97
# Sub-Saharan Africa                    2043.25
# Name: Total Revenue, dtype: float64

# %%
plt.figure(figsize=(12,6))

sns.boxplot(
    data=df,
    x='Region',
    y='Total Revenue'
)

plt.xticks(rotation=45)

plt.show()

# %%
df['Profit Percentage'] = (df['Total Profit']/df['Total Revenue'])*100

df.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit  Profit Percentage
# ...

# %%
df.to_csv("Sales_EDA_Output.csv", index=False)
